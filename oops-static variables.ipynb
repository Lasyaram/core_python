# %%
Types of variables:
    static variable(object level variable)
    instance variable (class level variable)
    local variable  (method level variable)
    global variable

# %%
#variaous places to declare static variable
class Test:
    a=10 # static variable
    b=30
    c=80
    def __init__(self):
        self.a=10
        self.b=20 # static variable
        Test.d=30  # inside constructor using class name to declare static variable
    def m1(self):  # noraml method
        Test.e=40  # inside method using class name to declare static variable
    @classmethod  # class method calling (decorator)
    def m2(cls):
        Test.f=50 # inside class method using class name to declare static variable
        cls.g=60  # inside class method using cls variable to declare static variable
    @staticmethod # static method calling (decorator)
    def static():
        Test.h=70 # inside static method using class name to declare static variable

# %%
# accessing / calling variable

#variaous places to declare static variable
class Test:
    a=10 # static variable
    b=30
    c=80
    def __init__(self):
        
        print(self.a) 
          # inside constructor using self to acess static variable
        print(Test.a) # inside constructor using class name to call static variable
    def m1(self):  #instance method
        print(self.a) 
          # inside constructor using self to acess static variable
        print(Test.a) # inside constructor using class name to call static variable
    @staticmethod
    def m2():
        print(Test.a) # inside static method using class name to call static variab
        
    @classmethod
    def m3(cls):
        print(cls.a)# inside class method using class variable=========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== to call static var
        print(Test.a) # inside class method using class name to call static var
print(t.a)
print(Test.a)

t=Test()
t.m1()
t.m2()
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10

# %%
# calling staitic

t=Test()  # reffernce variable for the class to create the object
print(t.a)  # calling static variable through object refernce
print(Test.a)# through class name
print(x)  # calling global variable
# Out:
# 10
# 10
# 30

# %%
# modify the static variable

class New():
    a=10
    def __init
    @classmethod
    def m1(cls):
        cls.a=20
    @staticmethod
    def m2():
        New.a=30
    
    
    
n=New()  # refernece object/ creation fo the object from the class
print(n.a)
print(New.a)
New.m1()# method calling
print(New.a) # variable calling for static method
New.m2()
print(New.a)
# Out:
# 10
# 10
# 20
# 30

# %%
# deleting the ststic variable
# modify the static variable

class New():
    a=10
    @classmethod
    def m1(cls):
        del cls.a
    @staticmethod
    def m2():
        del New.a
    
n=New()
print(New.a)
# Out:
# 10

# %%
del a

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-bca0e2660b9f> in <module>
# ----> 1 print(a)
#
# NameError: name 'a' is not defined
